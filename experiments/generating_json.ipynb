# %% [markdown]
# # Novel condition image pairing only

# %%
import os
import json
import random

# Define path for NOVEL condition
root_path = os.getcwd()
novel_path = os.path.join(root_path, 'Stimuli', 'Novel pairs (tested)')

# Function to get image pairs for the NOVEL condition with flexible matching
def get_image_pairs_novel(condition_path):
    pairs = []
    
    # Get all .jpg files, excluding 'Thumbs.db'
    files = sorted([f for f in os.listdir(condition_path) if f.lower().endswith('.jpg') and not f.startswith('Thumbs.db')])
    
    # Debug: Print the list of files found
    print(f"Files found in {condition_path}: {files}")
    
    # Group files based on the first three characters to create pairs
    grouped_files = {}
    for f in files:
        base = f[:3]  # Base identifier (e.g., 'n01')
        if base not in grouped_files:
            grouped_files[base] = []
        grouped_files[base].append(f)
    
    # Debug: Show grouped files by base name
    print(f"Grouped files by base name (first three characters): {grouped_files}")
    
    # Identify valid pairs with explicit check for 'a' and 'b'
    for base, file_list in grouped_files.items():
        a_file = next((f for f in file_list if 'a' in f[3:]), None)
        b_file = next((f for f in file_list if 'b' in f[3:]), None)
        if a_file and b_file:
            pairs.append({
                'image1': os.path.join('Stimuli', 'Novel pairs (tested)', a_file),
                'image2': os.path.join('Stimuli', 'Novel pairs (tested)', b_file)
            })
            
            # Debug: Log successful pairing
            print(f"Pair found: {a_file} and {b_file}")
    
    # Print initial total pairs found
    initial_pair_count = len(pairs)
    print(f"Total pairs initially found for NOVEL condition: {initial_pair_count}")
    
    # Limit to 50 pairs if more are found
    final_pairs = random.sample(pairs, min(50, initial_pair_count))
    print(f"Total pairs selected for NOVEL condition (limited to 50): {len(final_pairs)}")

    return final_pairs

# Get NOVEL pairs & prepare JSON structure
novel_pairs = get_image_pairs_novel(novel_path)
json_data = [{'condition': 'NOVEL', 'image1': pair['image1'], 'image2': pair['image2']} for pair in novel_pairs]

# Output JSON file
with open('novel_pairs.json', 'w') as json_file:
    json.dump(json_data, json_file, indent=2)

print('Successfully generated novel_pairs.json with pairs for the NOVEL condition.')
# Out:
# Files found in /Users/edwinruiz/Downloads/a_Current_Work/Academia/UCSD_courses/current/Fall24/cogs119/project/group_repo/latest/cogs119_testrepo/Stimuli/Novel pairs (tested): ['n01aladybug.jpg', 'n01bcoin.jpg', 'n02aaxe.jpg', 'n02bsafetypin.jpg', 'n03acamel.jpg', 'n03bbagel.jpg', 'n04ayarn.jpg', 'n04bbandaid.jpg', 'n05abarrel.jpg', 'n05bcactus.jpg', 'n06acane.jpg', 'n06blipstick.jpg', 'n07apotato.jpg', 'n07bswimmingpool.jpg', 'n08aoven.jpg', 'n08bpaperclip.jpg', 'n09apenguin.jpg', 'n09bsaddle.jpg', 'n10awindmill.jpg', 'n10bturkey.jpg', 'n11abatteries.jpg', 'n11bsock.jpg', 'n12atelescope.jpg', 'n12bwatch.jpg', 'n13ablueberries.jpg', 'n13bdustpan.jpg', 'n14acigarette.j
 'n49bhydrant.jpg'], 'n50': ['n50alobster.jpg', 'n50bironingboard.jpg'], 'n51': ['n51alantern.jpg', 'n51bwheelbarrow.jpg'], 'n52': ['n52alightbulb.jpg', 'n52bcanopener.jpg'], 'n53': ['n53acoffeepot.jpg', 'n53bbat.jpg'], 'n54': ['n54abaseballcap.jpg', 'n54bpooltable.jpg'], 'n55': ['n55acat.jpg', 'n55bpencil.jpg'], 'n56': ['n56aspoon.jpg', 'n56bcanteloupe.jpg'], 'n57': ['n57abed.jpg', 'n57bcandle.jpg'], 'n58': ['n58abasket.jpg', 'n58bbarette.jpg'], 'n59': ['n59abowl.jpg', 'n59bcupcake.jpg'], 'n60': ['n60azebra.jpg', 'n60bwashingmachine.jpg']}
# Pair found: n01aladybug.jpg and n01aladybug.jpg
# Pair found: n02aaxe.jpg and n02bsafetypin.jpg
# Pair found: n03acamel.jpg and n03bbagel.jpg
# Pair found: n04ayarn.jpg and n04bbandaid.jpg
# Pair found: n05abarrel.jpg and n05abarrel.jpg
# Pair found: n06acane.jpg and n06blipstick.jpg
# Pair found: n07apotato.jpg and n07bswimmingpool.jpg
# Pair found: n08aoven.jpg and n08bpaperclip.jpg
# Pair found: n09apenguin.jpg and n09bsaddle.jpg
# Pair found: n10awindmill.jpg and n10bturkey.jpg
# Pair found: n11abatteries.jpg and n11abatteries.jpg
# Pair found: n12atelescope.jpg and n12bwatch.jpg
# Pair found: n13ablueberries.jpg and n13ablueberries.jpg
# Pair found: n14acigarette.jpg and n14bgolfball.jpg
# Pair found: n15aspiderweb.jpg and n15aspiderweb.jpg
# Pair found: n16abananas.jpg and n16abananas.jpg
# Pair found: n17avendingmachine.jpg and n17bweddingdress.jpg
# Pair found: n18apretzel.jpg and n18bsnail.jpg
# Pair found: n19apickle.jpg and n19bhairbrush.jpg
# Pair found: n20acarseat.jpg and n20bshelf.jpg
# Pair found: n21aruler.jpg and n21bigloo.jpg
# Pair found: n22aknife.jpg and n22bmixer.jpg
# Pair found: n23alawnmower.jpg and n23bhammock.jpg
# Pair found: n24aswan.jpg and n24bfireextinguisher.jpg
# Pair found: n25asewingmachine.jpg and n25blegos.jpg
# Pair found: n26acomputermouse.jpg and n26bpeeler.jpg
# Pair found: n27alaundrybasket.jpg and n27alaundrybasket.jpg
# Pair found: n28alock.jpg and n28bolive.jpg
# Pair found: n29alighthouse.jpg and n29bharmonica.jpg
# Pair found: n30agrater.jpg and n30biceskates.jpg
# Pair found: n31ahourglass.jpg and n31bcamera.jpg
# Pair found: n32abroom.jpg and n32abroom.jpg
# Pair found: n33aclothespin.jpg and n33bpaintbrush.jpg
# Pair found: n34askateboard.jpg and n34askateboard.jpg
# Pair found: n35asnowflake.jpg and n35bcanoe.jpg
# Pair found: n36aeggs.jpg and n36bcrib.jpg
# Pair found: n37acherry.jpg and n37bbulldozer.jpg
# Pair found: n38acomputer.jpg and n38bearth.jpg
# Pair found: n39aring.jpg and n39bdoorknob.jpg
# Pair found: n40aflashlight.jpg and n40bgiraffe.jpg
# Pair found: n41afunnel.jpg and n41bhotdog.jpg
# Pair found: n42aharp.jpg and n42bwateringcan.jpg
# Pair found: n43afloppydisk.jpg and n43bdresser.jpg
# Pair found: n44adeer.jpg and n44bdiscoball.jpg
# Pair found: n45aflowerpot.jpg and n45bcuttingboard.jpg
# Pair found: n46acushion.jpg and n46bfaucet.jpg
# Pair found: n47ablender.jpg and n47ablender.jpg
# Pair found: n48afrenchfries.jpg and n48blighter.jpg
# Pair found: n49ahorse.jpg and n49bhydrant.jpg
# Pair found: n50alobster.jpg and n50alobster.jpg
# Pair found: n51alantern.jpg and n51bwheelbarrow.jpg
# Pair found: n52alightbulb.jpg and n52alightbulb.jpg
# Pair found: n53acoffeepot.jpg and n53bbat.jpg
# Pair found: n54abaseballcap.jpg and n54abaseballcap.jpg
# Pair found: n55acat.jpg and n55bpencil.jpg
# Pair found: n56aspoon.jpg and n56bcanteloupe.jpg
# Pair found: n57abed.jpg and n57abed.jpg
# Pair found: n58abasket.jpg and n58abasket.jpg
# Pair found: n59abowl.jpg and n59abowl.jpg
# Pair found: n60azebra.jpg and n60azebra.jpg
# Total pairs initially found for NOVEL condition: 60
# Total pairs selected for NOVEL condition (limited to 50): 50
# Successfully generated novel_pairs.json with pairs for the NOVEL condition.

# %% [markdown]
# # Novel, Exemplar, and State image pairing

# %%
# Define root path for 'Stimuli' directory 
root_path = os.getcwd()

# Define conditions & their paths
conditions = {
    "EXEMPLAR": os.path.join(root_path, 'Stimuli', 'EXEMPLAR'),
    "STATE": os.path.join(root_path, 'Stimuli', 'STATE'),
    "NOVEL": os.path.join(root_path, 'Stimuli', 'Novel pairs (tested)')
}

# Function to get image pairs for EXEMPLAR and STATE
def get_image_pairs_exemplar_state(condition_path, condition_name):
    pairs = []
    subdirs = ['USED', 'UNUSED', 'UNUSED-the rest of them']
    for subdir in subdirs:
        subdir_path = os.path.join(condition_path, subdir)
        if os.path.exists(subdir_path):
            
            # Get all image files in subdirectory, excluding 'Thumbs.db'
            files = [f for f in os.listdir(subdir_path) if f.lower().endswith('.jpg') and not f.startswith('Thumbs.db')]
            files.sort()  # Ensure pairs are sequentially organized
            base_names = {}
            for f in files:
                base = f[:-5]
                if base not in base_names:
                    base_names[base] = []
                base_names[base].append(os.path.join('Stimuli', condition_name, subdir, f))
            for images in base_names.values():
                if len(images) == 2:
                    pairs.append({'image1': images[0], 'image2': images[1]})
    
    # Print initial total pairs found
    initial_pair_count = len(pairs)
    print(f"Total pairs initially found for {condition_name} condition: {initial_pair_count}")

    # Limit to 50 pairs if more are found
    final_pairs = random.sample(pairs, min(50, initial_pair_count))
    print(f"Total pairs selected for {condition_name} condition (limited to 50): {len(final_pairs)}")

    return final_pairs

# Function to get image pairs for NOVEL condition with flexible matching
def get_image_pairs_novel(condition_path):
    pairs = []
    
    # Get all .jpg files, excluding 'Thumbs.db'
    files = sorted([f for f in os.listdir(condition_path) if f.lower().endswith('.jpg') and not f.startswith('Thumbs.db')])
    
    # Group files based on the first three characters to create pairs
    grouped_files = {}
    for f in files:
        base = f[:3]  # Base identifier (e.g., 'n01')
        if base not in grouped_files:
            grouped_files[base] = []
        grouped_files[base].append(f)
    
    # Identify valid pairs with explicit check for 'a' and 'b'
    for base, file_list in grouped_files.items():
        a_file = next((f for f in file_list if 'a' in f[3:]), None)
        b_file = next((f for f in file_list if 'b' in f[3:]), None)
        if a_file and b_file:
            pairs.append({
                'image1': os.path.join('Stimuli', 'Novel pairs (tested)', a_file),
                'image2': os.path.join('Stimuli', 'Novel pairs (tested)', b_file)
            })
            # Debug: Log successful pairing
            print(f"Pair found: {a_file} and {b_file}")
    
    # Print initial total pairs found
    initial_pair_count = len(pairs)
    print(f"Total pairs initially found for NOVEL condition: {initial_pair_count}")
    
    # Limit to 50 pairs if more are found
    final_pairs = random.sample(pairs, min(50, initial_pair_count))
    print(f"Total pairs selected for NOVEL condition (limited to 50): {len(final_pairs)}")

    return final_pairs

# Collect & sample image pairs for each condition
all_pairs = {
    'EXEMPLAR': get_image_pairs_exemplar_state(conditions['EXEMPLAR'], 'EXEMPLAR'),
    'STATE': get_image_pairs_exemplar_state(conditions['STATE'], 'STATE'),
    'NOVEL': get_image_pairs_novel(conditions['NOVEL'])
}

# Preparing JSON structure
json_data = []
for condition, pairs in all_pairs.items():
    for pair in pairs:
        json_data.append({
            'condition': condition,
            'image1': pair['image1'],
            'image2': pair['image2']
        })

# Output JSON file
with open('stimuli_pairs.json', 'w') as json_file:
    json.dump(json_data, json_file, indent=2)

print('Generated stimuli_pairs.json with pairs for each condition.')
# Out:
# Total pairs initially found for EXEMPLAR condition: 157
# Total pairs selected for EXEMPLAR condition (limited to 50): 50
# Total pairs initially found for STATE condition: 99
# Total pairs selected for STATE condition (limited to 50): 50
# Pair found: n01aladybug.jpg and n01aladybug.jpg
# Pair found: n02aaxe.jpg and n02bsafetypin.jpg
# Pair found: n03acamel.jpg and n03bbagel.jpg
# Pair found: n04ayarn.jpg and n04bbandaid.jpg
# Pair found: n05abarrel.jpg and n05abarrel.jpg
# Pair found: n06acane.jpg and n06blipstick.jpg
# Pair found: n07apotato.jpg and n07bswimmingpool.jpg
# Pair found: n08aoven.jpg and n08bpaperclip.jpg
# Pair found: n09apenguin.jpg and n09bsaddle.jpg
# Pair found: n10awindmill.jpg and n10bturkey.jpg
# Pair found: n11abatteries.jpg and n11abatteries.jpg
# Pair found: n12atelescope.jpg and n12bwatch.jpg
# Pair found: n13ablueberries.jpg and n13ablueberries.jpg
# Pair found: n14acigarette.jpg and n14bgolfball.jpg
# Pair found: n15aspiderweb.jpg and n15aspiderweb.jpg
# Pair found: n16abananas.jpg and n16abananas.jpg
# Pair found: n17avendingmachine.jpg and n17bweddingdress.jpg
# Pair found: n18apretzel.jpg and n18bsnail.jpg
# Pair found: n19apickle.jpg and n19bhairbrush.jpg
# Pair found: n20acarseat.jpg and n20bshelf.jpg
# Pair found: n21aruler.jpg and n21bigloo.jpg
# Pair found: n22aknife.jpg and n22bmixer.jpg
# Pair found: n23alawnmower.jpg and n23bhammock.jpg
# Pair found: n24aswan.jpg and n24bfireextinguisher.jpg
# Pair found: n25asewingmachine.jpg and n25blegos.jpg
# Pair found: n26acomputermouse.jpg and n26bpeeler.jpg
# Pair found: n27alaundrybasket.jpg and n27alaundrybasket.jpg
# Pair found: n28alock.jpg and n28bolive.jpg
# Pair found: n29alighthouse.jpg and n29bharmonica.jpg
# Pair found: n30agrater.jpg and n30biceskates.jpg
# Pair found: n31ahourglass.jpg and n31bcamera.jpg
# Pair found: n32abroom.jpg and n32abroom.jpg
# Pair found: n33aclothespin.jpg and n33bpaintbrush.jpg
# Pair found: n34askateboard.jpg and n34askateboard.jpg
# Pair found: n35asnowflake.jpg and n35bcanoe.jpg
# Pair found: n36aeggs.jpg and n36bcrib.jpg
# Pair found: n37acherry.jpg and n37bbulldozer.jpg
# Pair found: n38acomputer.jpg and n38bearth.jpg
# Pair found: n39aring.jpg and n39bdoorknob.jpg
# Pair found: n40aflashlight.jpg and n40bgiraffe.jpg
# Pair found: n41afunnel.jpg and n41bhotdog.jpg
# Pair found: n42aharp.jpg and n42bwateringcan.jpg
# Pair found: n43afloppydisk.jpg and n43bdresser.jpg
# Pair found: n44adeer.jpg and n44bdiscoball.jpg
# Pair found: n45aflowerpot.jpg and n45bcuttingboard.jpg
# Pair found: n46acushion.jpg and n46bfaucet.jpg
# Pair found: n47ablender.jpg and n47ablender.jpg
# Pair found: n48afrenchfries.jpg and n48blighter.jpg
# Pair found: n49ahorse.jpg and n49bhydrant.jpg
# Pair found: n50alobster.jpg and n50alobster.jpg
# Pair found: n51alantern.jpg and n51bwheelbarrow.jpg
# Pair found: n52alightbulb.jpg and n52alightbulb.jpg
# Pair found: n53acoffeepot.jpg and n53bbat.jpg
# Pair found: n54abaseballcap.jpg and n54abaseballcap.jpg
# Pair found: n55acat.jpg and n55bpencil.jpg
# Pair found: n56aspoon.jpg and n56bcanteloupe.jpg
# Pair found: n57abed.jpg and n57abed.jpg
# Pair found: n58abasket.jpg and n58abasket.jpg
# Pair found: n59abowl.jpg and n59abowl.jpg
# Pair found: n60azebra.jpg and n60azebra.jpg
# Total pairs initially found for NOVEL condition: 60
# Total pairs selected for NOVEL condition (limited to 50): 50
# Generated stimuli_pairs.json with pairs for each condition.
